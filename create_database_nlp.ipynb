# %% [markdown]
# <a href="https://colab.research.google.com/github/ali-talebi/Csite/blob/create-branch-data/create_database_nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
def GET_DATA_WITH_LINK_FUNC(url) :
    response = requests.get(url)
    status_code = response.status_code

    soup = BeautifulSoup(response.text, 'html.parser')
    links = soup.find_all('a')
    a_link = []
    for link in links:
        try:
            new_link = ''
            url_ = link.get('href')
            if len(url_) > 1 :

                if url_[0] in ['#' , ':'  , '' , '?' ] or '.html' in  url_ :
                    continue

                elif url_[0] == '/' :
                    if url[-1] == '/' :
                        url = url[0:-1]
                    new_link = url + url_
                    a_link.append(new_link)


            elif 'https' in url_ or 'http' in url_ :
                new_link = url_

                a_link.append(new_link)

        except Exception as e:
            pass





    s_  = ""
    p_tags = soup.find_all('p')
    for p_tag in p_tags:
        p_text = p_tag.get_text(strip=True)
        a_tags = p_tag.find_all('a')
        a_texts = [a_tag.get_text(strip=True) for a_tag in a_tags]
        p_link_a = ', '.join(a_texts)
        p_tag.append(p_text)
        p_tag.append(p_link_a)
        s_ += p_text
        s_ += p_link_a


    server_name = " "
    if response.headers['server'] :
        server_name = response.headers['server']


    return status_code , a_link , s_ , server_name

# %%
list_site_path = "/content/drive/MyDrive/project_zamani_sohrevardi/tranco_W8L29.csv"
dataset = pd.read_csv( list_site_path , header = None )
dataset.columns =  ['index' , 'domain']
dataset.drop(['index'] , axis = 1 , inplace=True )

# %%
dataset
# Out:
#                    domain
# 0              google.com
# 1            a-msedge.net
# 2           microsoft.com
# 3            facebook.com
# 4           amazonaws.com
# ...                   ...
# 999995   smartwebwise.com
# 999996  smartwheels.autos
# 999997     smashkaart.com
# 999998     smb-service.kr
# 999999           smhrc.kr
#
# [1000000 rows x 1 columns]

# %%
get_data = {'domain':[] , 'get_tex':[]}

# %%
for domain in dataset.iloc[: 500 , 0 ] :
  if "https://" not in domain and "http://" not in domain :
    new_domain = "https://" + domain

  else :
    new_domain = domain
  try :
    status_code , a_link , s_ , server_name = GET_DATA_WITH_LINK_FUNC(new_domain)
    get_data['domain'].append(new_domain)
    get_data['get_tex'].append(s_)

  except Exception as e :
    print(e)
# Out:
# HTTPSConnectionPool(host='a-msedge.net', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ba3a0f829b0>: Failed to resolve 'a-msedge.net' ([Errno -5] No address associated with hostname)"))
# 'server'
# HTTPSConnectionPool(host='amazonaws.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7ba3a2103f40>: Failed to establish a new connection: [Errno 111] Connection refused'))
# 'server'
# HTTPSConnectionPool(host='root-servers.net', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ba3a0ce5ab0>: Failed to resolve 'root-servers.net' ([Errno -5] No address associated with hostname)"))
# ...

# %%
len(get_data['domain'])
# Out:
# 180

# %%
df1 = pd.DataFrame(get_data)

# %%
df1.to_csv('180_toal.csv' , index = False )

# %%
df1
# Out:
#                     domain                                            get_tex
# 0       https://google.com                © 2024 -Privacy-TermsPrivacy, Terms
# 1    https://microsoft.com
# 2        https://apple.com  Unbelievably thin. Incredibly powerful.Buy Mac...
# 3      https://youtube.com
# 4      https://twitter.com
# ..                     ...                                                ...
# 175        https://sapo.pt  As notícias, jornais e rádios locais, estão aq...
# 176     https://criteo.net
# 177   https://springer.com  With more than 2,900 journals and 300,000 book...
# 178     https://adform.net
# 179      https://quora.com  Something went wrong. Wait a moment and try ag...
#
# [180 rows x 2 columns]
